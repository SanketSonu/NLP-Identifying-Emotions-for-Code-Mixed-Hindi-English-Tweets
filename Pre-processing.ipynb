# %%
import re
import pandas as pd
import numpy as np

# %%
df = pd.read_excel('df - Combined.xlsx')
df

# %%
df.drop_duplicates(subset=['tweets'], keep='last', inplace=True)
df.reset_index(inplace=True)

# %%
df['id'] = df['id'].astype(str)
df['tweets'] = df['tweets'].astype(str)

df[df['tweets'].map(lambda x: x.isascii())]

# Cleaning tweets
def clean_tweets(text):
    text = re.sub(r'@[A-Za-z0-9_]+','',text)    # Removing @mentions
    text = re.sub(r'#','',text)                 # Removing #tag symbol
    text = re.sub(r'RT[\s]+',' ',text)          # Remvoing RT
    text = re.sub(r'\n','',text) 
    text = re.sub(r',','',text) 
    text = re.sub(r'.[.]+','',text) 
    text = re.sub(r'\w+:\/\/\S+','',text) 
    text = re.sub(r'https?:\/\/\S+','',text)    # Removing hyperlinks
    text = re.sub(r'/',' ',text)
    text = re.sub(r'-',' ',text)
    text = re.sub(r'_',' ',text)
    text = re.sub(r'!','',text)
    text = re.sub(r':',' ',text)
    text = re.sub(r'$','',text)
    text = re.sub(r'%','',text)
    text = re.sub(r'^','',text)
    text = re.sub(r'&','',text)
    text = re.sub(r'=',' ',text)
    text = re.sub(r' +',' ',text)               # Removing extra whitespaces

    return text

# Removing Emojis
def clean_emoji(inputString):
    return inputString.encode('ascii', 'ignore').decode('ascii')

# Changing spellings of few hindi common words
def spelling_checks(text):
    text = re.sub(r' bha ',' bhai ',text)
    text = re.sub(r' vai ',' bhai ',text)
    text = re.sub(r' hia ',' hai ',text)
    text = re.sub(r' hain ',' hai ',text)
    text = re.sub(r' hae ','hai',text)
    text = re.sub(r' haee','hai',text)
    text = re.sub(r' he ',' hai ',text)
    text = re.sub(r' h ',' hai ',text)
    text = re.sub(r' ha ',' hai ',text)
    text = re.sub(r' hen ',' hai ',text)
    text = re.sub(r' mai ',' main ',text)
    text = re.sub(r' mae ',' main ',text)
    text = re.sub(r' mein ',' main ',text) 
    text = re.sub(r' mainnnnnnn ',' main ',text) 
    text = re.sub(r' mainn ',' main ',text) 
    text = re.sub(r' mei ',' main ',text)
    text = re.sub(r' aap ',' ap ',text)
    text = re.sub(r' app ',' ap ',text)
    text = re.sub(r' aaap ',' ap ',text)
    text = re.sub(r' nahin ',' ni ',text)
    text = re.sub(r' nah ',' ni ',text)
    text = re.sub(r' nhe ',' ni ',text)
    text = re.sub(r' nahi ',' ni ',text)
    text = re.sub(r' nai ',' ni ',text)
    text = re.sub(r' nhi ',' ni ',text)
    text = re.sub(r' nahni ',' ni ',text)
    text = re.sub(r' ny ',' ni ',text)
    text = re.sub(r' nehi ',' ni ',text)
    text = re.sub(r' nehi ',' ni ',text)
    text = re.sub(r' naa ',' ni ',text)
    text = re.sub(r' na ',' ni ',text)
    text = re.sub(r' nae ',' ni ',text)
    text = re.sub(r' bhsdwala ',' bsdk ',text)
    text = re.sub(r' bsdiwala ',' bsdk ',text)
    text = re.sub(r' bhosadiwala ',' bsdk ',text)
    text = re.sub(r' chutiyaaa ',' chutiya ',text)
    text = re.sub(r' chu ',' chutiya ',text)
    text = re.sub(r' moka','mauka ',text)
    text = re.sub(r' sahram','sharam ',text)
    text = re.sub(r' shrm ',' sharam ',text)
    text = re.sub(r' sharm ',' sharam ',text)
    text = re.sub(r' shaaram ',' sharam ',text)
    text = re.sub(r' beiizat ',' beizzat ',text)
    text = re.sub(r' beizat ',' beizzat ',text)
    text = re.sub(r' beiizati ',' beizzat ',text)
    text = re.sub(r' beizati ',' beizzat ',text)
    text = re.sub(r' beizzati ',' beizzat ',text)
    text = re.sub(r' aur ',' or ',text)
    text = re.sub(r' or ',' aur ',text)
    text = re.sub(r' aaur ',' aur ',text)
    text = re.sub(r' q ',' kyu ',text)
    text = re.sub(r' kiyu ',' kyu ',text)
    text = re.sub(r' kyun ',' kyu ',text)
    text = re.sub(r' kiu ',' kyu ',text)
    text = re.sub(r' kue ',' kyu ',text)
    text = re.sub(r' kyyu ',' kyu ',text)
    text = re.sub(r' kyuu ',' kyu ',text)
    text = re.sub(r' kyon ',' kyu ',text)
    text = re.sub(r' aapko ',' apko ',text)
    text = re.sub(r' apkko ',' apko ',text)
    text = re.sub(r' ab ',' aab ',text)
    text = re.sub(r' abb ',' aab ',text)
    text = re.sub(r' bss ',' bas ',text)
    text = re.sub(r' bass ',' bas ',text)
    text = re.sub(r' hun ',' hn ',text)
    text = re.sub(r' hu ',' hn ',text)
    text = re.sub(r' han ',' hn ',text)
    text = re.sub(r' hoon ',' hn ',text)
    text = re.sub(r' hunn ',' hn ',text)
    text = re.sub(r' aj ',' aaj ',text)
    text = re.sub(r' ajj ',' aaj ',text)
    text = re.sub(r' aajj ',' aaj ',text)
    text = re.sub(r' kia ',' kya ',text)
    text = re.sub(r' kyaa ',' kya ',text)
    text = re.sub(r' keya ',' kya ',text)
    text = re.sub(r' kea ',' kya ',text)
    text = re.sub(r' kl ',' kal ',text)
    text = re.sub(r' n ',' and ',text)
    text = re.sub(r' dam ',' dumm',text)
    text = re.sub(r' damm ',' dumm ',text)
    text = re.sub(r' dumm ',' dam ',text)
    text = re.sub(r' amm ',' aam ',text)
    text = re.sub(r' sal ',' saal ',text)
    text = re.sub(r' bevkoof ',' bewakoof ',text)
    text = re.sub(r' bewakof ',' bewakoof ',text)
    text = re.sub(r' aacchha ',' acha ',text)
    text = re.sub(r' aacha ',' acha ',text)
    text = re.sub(r' aaccha ',' acha ',text)
    text = re.sub(r' hue ',' huy ',text)
    text = re.sub(r' huye ',' huy ',text)
    text = re.sub(r' bhagwaan ',' bhagwan ',text)
    text = re.sub(r' bhagvan ',' bhagwan ',text)
    text = re.sub(r' tou ',' toh ',text)
    text = re.sub(r' fikarr ',' fikar ',text)
    text = re.sub(r' fikkarr ',' fikar ',text)
    text = re.sub(r' fikaarr ',' fikar ',text)
    text = re.sub(r' chupp ',' chup ',text)
    text = re.sub(r' chuupp ',' chup ',text) 
    text = re.sub(r' jai hind ',' jaihind ',text)
    text = re.sub(r' byye ',' bye ',text)
    text = re.sub(r' byee ',' bye ',text)
    text = re.sub(r' hie ',' hi ',text)
    text = re.sub(r' hii ',' hi ',text)
    text = re.sub(r' yaarr ',' yaar ',text)
    text = re.sub(r' yawrrr ',' yaar ',text)
    text = re.sub(r' yar ',' yaar ',text)
    text = re.sub(r' yrr ',' yaar ',text)
    text = re.sub(r' yr ',' yaar ',text)
    text = re.sub(r' yrrr ',' yaar ',text)
    text = re.sub(r' yaaar ',' yaar ',text)
    text = re.sub(r' yaaaaaaar ',' yaar ',text)
    text = re.sub(r' yaaarrr ',' yaar ',text)
    text = re.sub(r' yarr ',' yaar ',text)
    text = re.sub(r' yaa ',' yaar ',text)
    text = re.sub(r' jyadaa ',' jyada ',text)
    text = re.sub(r' jyaada ',' jyada ',text)
    text = re.sub(r' btween ',' between ',text)
    text = re.sub(r' btwn ',' between ',text)
    text = re.sub(r' laayak ',' layak ',text)
    text = re.sub(r' laayaak ',' layak ',text)
    text = re.sub(r' hy ',' hi ',text)
    text = re.sub(r' sbse ',' sabse ',text)
    text = re.sub(r' awww ',' aww ',text)
    text = re.sub(r' aw ',' aww ',text)
    text = re.sub(r' awwww ',' aww ',text)
    text = re.sub(r' awwwww ',' aww ',text)
    text = re.sub(r' nicee ',' nice ',text)
    text = re.sub(r' nic ',' nice ',text)
    text = re.sub(r' niccee ',' nice ',text)
    text = re.sub(r' niceee ',' nice ',text)
    text = re.sub(r' happyy ',' happy ',text)
    text = re.sub(r' hppy ',' happy ',text)
    text = re.sub(r' hapy ',' happy ',text)
    text = re.sub(r' happii ',' happy ',text)
    text = re.sub(r' hpy ',' happy ',text)
    text = re.sub(r' thank you ',' thankyou ',text)
    text = re.sub(r' thanku ',' thankyou ',text)
    text = re.sub(r' thnk you ',' thankyou ',text)
    text = re.sub(r' thank u ',' thankyou ',text)
    text = re.sub(r' thankuu ',' thankyou ',text)
    text = re.sub(r' thkyu ',' thankyou ',text)
    text = re.sub(r' u ',' you ',text)
    text = re.sub(r' yo ',' you ',text)
    text = re.sub(r' lgta ',' lagta ',text)
    text = re.sub(r' lagtaa ',' lagta ',text)
    text = re.sub(r' laggta ',' lagta ',text)
    text = re.sub(r' tjhe ',' tujhe ',text)
    text = re.sub(r' tujjhe ',' tujhe ',text)
    text = re.sub(r' laae ',' lae ',text)
    text = re.sub(r' laee ',' lae ',text)
    text = re.sub(r' mtlb ',' matlab ',text)
    text = re.sub(r' matlb ',' matlab ',text)
    text = re.sub(r' aram ',' aaram ',text)
    text = re.sub(r' aarraamm ',' aaram ',text)
    text = re.sub(r' toh ',' to ',text)
    text = re.sub(r' huya ',' hua ',text)
    text = re.sub(r' huwa ',' hua ',text)
    text = re.sub(r' tmharaa ',' tmhara ',text)
    text = re.sub(r' tumhara ',' tmhara ',text)
    text = re.sub(r' tumara ',' tmhara ',text)
    text = re.sub(r' tmhare ',' tmhara ',text)
    text = re.sub(r' woh ',' wo ',text)
    text = re.sub(r' nhi ',' ni ',text)
    text = re.sub(r' gaey ',' gae ',text)
    text = re.sub(r' gaye ',' gae ',text)
    text = re.sub(r' nhi ',' ni ',text)
    text = re.sub(r' name ',' naam ',text)
    text = re.sub(r' nam ',' naam ',text)
    text = re.sub(r' naaam ',' naam ',text)
    text = re.sub(r' pls ',' please ',text)
    text = re.sub(r' plz ',' please ',text)
    text = re.sub(r' plzz ',' please ',text)
    text = re.sub(r' plzzz ',' please ',text)
    text = re.sub(r' pleas ',' please ',text)
    text = re.sub(r' plss ',' please ',text)
    text = re.sub(r' pleasee ',' please ',text)
    text = re.sub(r' pleaseee ',' please ',text)
    text = re.sub(r' nahni ',' ni ',text)
    text = re.sub(r' dearrrr ',' dear ',text)
    text = re.sub(r' dearrr ',' dear ',text)
    text = re.sub(r' dearr ',' dear ',text)
    text = re.sub(r' dearrrrr ',' dear ',text)
    text = re.sub(r' han ',' haan ',text)
    text = re.sub(r' hann ',' haan ',text)
    text = re.sub(r' haa ',' haan ',text)
    text = re.sub(r' gee ',' ji ',text)
    text = re.sub(r' ge ',' ji ',text)
    text = re.sub(r' g ',' ji ',text)
    text = re.sub(r' jii ',' ji ',text)
    text = re.sub(r' mahol ',' mahaul ',text)
    text = re.sub(r' mahool ',' mahaul ',text)
    text = re.sub(r' mahaol ',' mahaul ',text)
    text = re.sub(r' pyar ',' pyaar ',text)
    text = re.sub(r' pyarr ',' pyaar ',text)
    text = re.sub(r' mujh ',' mujhe ',text)
    text = re.sub(r' mujhee ',' mujhe ',text)
    text = re.sub(r' mjhe ',' mujhe ',text)
    text = re.sub(r' muje ',' mujhe ',text)
    text = re.sub(r' muj ',' mujhe ',text)
    text = re.sub(r' hahaha ',' haha ',text)
    text = re.sub(r' hahahhaha ',' haha ',text)
    text = re.sub(r' hahhaa ',' haha ',text)
    text = re.sub(r' hahahaa ',' haha ',text)
    text = re.sub(r' isi ',' issi ',text)
    text = re.sub(r' rahein ',' rahe ',text)
    text = re.sub(r' mazak ',' mazzak ',text)
    text = re.sub(r' mazakk ',' mazzak ',text)
    text = re.sub(r' kar ',' kr ',text)
    text = re.sub(r' ker ',' kr ',text)
    text = re.sub(r' baar ',' bar ',text)
    text = re.sub(r' waale ',' wale ',text)
    text = re.sub(r' jaaye ',' jaye ',text)
    text = re.sub(r' jaay ',' jaye ',text)
    text = re.sub(r' jae ',' jaye ',text)
    text = re.sub(r' jaein ',' jaye ',text)
    text = re.sub(r' raha ',' rha ',text)
    text = re.sub(r' rahe ',' rha ',text)
    text = re.sub(r' rahi ',' rha ',text)
    text = re.sub(r' rhi ',' rha ',text)
    text = re.sub(r' rhe ',' rha ',text)
    text = re.sub(r' yeah ',' yes ',text)
    text = re.sub(r' yeahh ',' yes ',text)
    text = re.sub(r' yea ',' yes ',text)
    text = re.sub(r' yess ',' yes ',text)
    text = re.sub(r' bap ',' baap ',text)
    text = re.sub(r' aulad ',' aulaad ',text)
    text = re.sub(r' tw ',' to ',text)
    text = re.sub(r' tau ',' to ',text)
    text = re.sub(r' too ',' to ',text)
    text = re.sub(r' toh ',' to ',text)
    text = re.sub(r' chii ',' chi ',text)
    text = re.sub(r' chiii ',' chi ',text)
    text = re.sub(r' hamne ',' humne ',text)
    text = re.sub(r' hmne ',' humne ',text)
    text = re.sub(r' humney ',' humne ',text)
    text = re.sub(r' hmney ',' humne ',text)
    text = re.sub(r' ham ',' hum ',text)
    text = re.sub(r' humm ',' hum ',text)
    text = re.sub(r' hm ',' hum ',text)
    text = re.sub(r' kee ',' k ',text)
    text = re.sub(r' ke ',' k ',text)
    text = re.sub(r' smjh ',' samajh ',text)
    text = re.sub(r' krteee ',' krte ',text)
    text = re.sub(r' krty ',' krte ',text)
    text = re.sub(r' krtey ',' krte ',text)
    text = re.sub(r' kerte ',' krte ',text)
    text = re.sub(r' dimak ',' dimaag ',text)
    text = re.sub(r' dimag ',' dimaag ',text)
    text = re.sub(r' dhimag ',' dimaag ',text)
    text = re.sub(r' gay ',' gaya ',text)
    text = re.sub(r' gai ',' gaya ',text)
    text = re.sub(r' gea ',' gaya ',text)
    text = re.sub(r' geye ',' gaya ',text)
    text = re.sub(r' geya ',' gaya ',text)
    text = re.sub(r' jaeg ',' jaega ',text)
    text = re.sub(r' jaeega ',' jaega ',text)
    text = re.sub(r' mainne ',' maine ',text)
    text = re.sub(r' mainey ',' maine ',text)
    text = re.sub(r' dar ',' darr ',text)
    text = re.sub(r' dekheg ',' dekhege ',text)
    text = re.sub(r' dkhnge ',' dekhege ',text)
    text = re.sub(r' dkhng ',' dekhege ',text)
    text = re.sub(r' dkhe ',' dekhe ',text)
    text = re.sub(r' dekhey ',' dekhe ',text)
    text = re.sub(r' dkhey ',' dekhe ',text)
    text = re.sub(r' detey ',' dete ',text)
    text = re.sub(r' dety ',' dete ',text)
    text = re.sub(r' diy ',' diya ',text)
    text = re.sub(r' liy ',' liya ',text)
    text = re.sub(r' lia ',' liya ',text)
    text = re.sub(r' kiy ',' kiya ',text)
    text = re.sub(r' skte ',' sakte ',text)
    text = re.sub(r' skty ',' sakte ',text)
    text = re.sub(r' sktey ',' sakte ',text)
    text = re.sub(r' kch ',' kuch ',text)
    text = re.sub(r' kuc ',' kuch ',text)
    text = re.sub(r' lgta ',' lagta ',text)
    text = re.sub(r' lgty ',' lagta ',text)
    text = re.sub(r' lagty ',' lagta ',text)
    text = re.sub(r' lagtae ',' lagta ',text)
    text = re.sub(r' mtt ',' matt ',text)
    text = re.sub(r' mattt ',' matt ',text)
    text = re.sub(r' bhe ',' bhi ',text)
    text = re.sub(r' v ',' bhi ',text)
    text = re.sub(r' b ',' bhi ',text)
    text = re.sub(r' bh ',' bhi ',text)
    text = re.sub(r' bi ',' bhi ',text)
    text = re.sub(r' jese ',' jaise ',text)
    text = re.sub(r' jaisy ',' jaise ',text)
    text = re.sub(r' jaisey ',' jaise ',text)
    text = re.sub(r' jesy ',' jaise ',text)
    text = re.sub(r' jase ',' jaise ',text)
    text = re.sub(r' beyshaaram ',' besharam ',text)
    text = re.sub(r' beshaaramoon ',' besharam ',text)
    text = re.sub(r' besharam ',' besharam ',text)
    text = re.sub(r' beysharam ',' besharam ',text)
    text = re.sub(r' byshermo ',' besharam ',text)
    text = re.sub(r' rkh ',' rakh ',text)
    text = re.sub(r' kesa ',' kaisa ',text)
    text = re.sub(r' kaese ',' kaise ',text)
    text = re.sub(r' kese ',' kaise ',text)
    text = re.sub(r' kesse ',' kaise ',text)
    text = re.sub(r' kase ',' kaise ',text)
    text = re.sub(r' thaa ',' tha ',text)
    text = re.sub(r' laag ',' lag ',text)
    text = re.sub(r' lg ',' lag ',text)
    text = re.sub(r' lagg ',' lag ',text)
    text = re.sub(r' kam ',' kaam ',text)
    text = re.sub(r' kaamm ',' kaam ',text)
    text = re.sub(r' sai ',' se ',text)
    text = re.sub(r' sey ',' se ',text)
    text = re.sub(r' sy ',' se ',text)
    text = re.sub(r' her ',' har ',text)
    text = re.sub(r' hr ',' har ',text)
    text = re.sub(r' aik ',' ek ',text)
    text = re.sub(r' ak ',' ek ',text)
    text = re.sub(r' ik ',' ek ',text)
    text = re.sub(r' tumhen ',' tumhe ',text)
    text = re.sub(r' tmhey ',' tumhe ',text)
    text = re.sub(r' tmhein ',' tumhe ',text)
    text = re.sub(r' tumhein ',' tumhe ',text)
    text = re.sub(r' tumhain ',' tumhe ',text)
    text = re.sub(r' tmhe ',' tumhe ',text)
    text = re.sub(r' tmko ',' tumhe ',text)
    text = re.sub(r' baygairat ',' beghairat ',text)
    text = re.sub(r' behairat ',' beghairat ',text)
    text = re.sub(r' beghairatt ',' beghairat ',text)
    text = re.sub(r' mar ',' marr ',text)
    text = re.sub(r' mer ',' marr ',text)
    text = re.sub(r' muu ',' muh ',text)
    text = re.sub(r' moo ',' muh ',text)
    text = re.sub(r' mooh ',' muh ',text)
    text = re.sub(r' mu ',' muh ',text)
    text = re.sub(r' jb ',' jab ',text)
    text = re.sub(r' jabb ',' jab ',text)
    text = re.sub(r' bhen ',' behan ',text)
    text = re.sub(r' behen ',' behan ',text)
    text = re.sub(r' bahan ',' behan ',text)
    text = re.sub(r' bhn ',' behan ',text)
    text = re.sub(r' bhan ',' behan ',text)
    text = re.sub(r' bhain ',' behan ',text)
    text = re.sub(r' rah ',' reh ',text)
    text = re.sub(r' rh ',' reh ',text)
    text = re.sub(r' fan ',' fans ',text)
    text = re.sub(r' fandom ',' fans ',text)
    text = re.sub(r' thn ',' than ',text)
    text = re.sub(r' ta ',' tha ',text)
    text = re.sub(r' prblm ',' problem ',text)
    text = re.sub(r' gvmnt ',' government ',text)
    text = re.sub(r' gvt ',' government ',text)
    text = re.sub(r' gov ',' government ',text)
    text = re.sub(r' gvmt ',' government ',text)
    text = re.sub(r' eesi ',' aisa ',text)
    text = re.sub(r' ese ',' aisa ',text)
    text = re.sub(r' esse ',' aisa ',text)
    text = re.sub(r' essa ',' aisa ',text)
    text = re.sub(r' aesa ',' aisa ',text)
    text = re.sub(r' ais ',' aisa ',text)
    text = re.sub(r' r ',' re ',text)
    text = re.sub(r' disapointed ',' disappointed ',text)
    text = re.sub(r' chnnel ',' channel ',text)
    text = re.sub(r' chnnl ',' channel ',text)
    text = re.sub(r' inse ',' isse ',text)
    text = re.sub(r' ense ',' isse ',text)
    text = re.sub(r' esse ',' isse ',text)

    return text

df['tweets'] = df['tweets'].apply(clean_tweets)
df['tweets'] = df['tweets'].apply(clean_emoji)
df['tweets'] = df['tweets'].apply(spelling_checks)
df['tweets'] = df.tweets.str.lower()      
df['tweets'] = df['tweets'].str.strip()            # Removing leading and trailing whitespaces
#pd.set_option('display.max_rows', None)
#pd.set_option('display.max_colwidth', -1)
df

# %%
df['id'] = df['id'].astype(str)      
df.to_excel('Code Mixed Hindi-English tweets.xlsx')
